# %%
import pandas as pd

df= pd.read_csv('D:/dl/test.csv')
df.dropna(how='all')
# Out:
#                 npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0        1003000126                    ENKESHAFI                   ARDALAN
# 1        1003000142                       KHALIL                    RASHID
# 2        1003000167                      ESCOBAR                     JULIO
# 3        1003000175                REYES-VASQUEZ                   BELINDA
# 4        1003000282                    BLAKEMORE                     ROSIE
# ...             ...                          ...                       ...
# 1048570  1902149081                         KOCH                 CHRISTINA
# 1048571  1902149099                        RAMAY                    FARIHA
# 1048572  1902149123                       BLYTHE                     KEVIN
# 1048573  1902149149                      OYEDEJI                   CHARITY
# 1048574  1902149198                     JOFFRION                     CINDY
#
#         nppes_provider_mi nppes_credentials nppes_provider_gender  \
# ...

# %%
d=df[['bene_count','npi']].groupby(['npi']).mean()

d[d.bene_count> 10]
d.dropna(axis='columns')
d.to_csv('D:/dl/d.csv')

# %%
av
# Out:
# npi
# 1003000126    234.0
# 1003000142    276.0
# 1003000167     33.0
# 1003000175      NaN
# 1003000282     11.0
#               ...
# 1902149081     53.0
# 1902149099      NaN
# 1902149123     62.0
# 1902149149     21.0
# 1902149198    304.0
# Name: bene_count, Length: 1048575, dtype: float64
